# %%
# dtShuffled = shuffle(dtFrame, random_state = 3333)

# # calculando el percentil 80 del vector a

# perc_80 = np.percentile(a, 80)



# # creando el vector check

# check = (a<perc_80)

# %%
import pandas as pd

# %%
merah_wine=pd.read_csv('../GitHub/python-ml-course/datasets/wine/winequality-red.csv',sep=';')

# %%
merah_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
merah_wine.columns.values
# Out:
# array(['fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'], dtype=object)

# %%
merah_wine.shape
# Out:
# (1599, 12)

# %%
putih_wine=pd.read_csv('../GitHub/python-ml-course/datasets/wine/winequality-white.csv',sep=';')

# %%
putih_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
putih_wine.shape
# Out:
# (4898, 12)

# %% [markdown]
# En python hay dos tipos de ejes:
#
# * Eje horizontal: Denotado como axis= 0
# * Eje vertical: Denotado como axis= 1

# %%
wine_data=pd.concat((merah_wine,putih_wine),axis=0)

# %%
wine_data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
data1=wine_data[:10]
data2=wine_data[300:310]
data3=wine_data.tail(10)

wine_data_2=pd.concat((data2,data1,data3),axis=0)

# %%
wine_data_2
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 300             7.5             0.530         0.06            2.60      0.086
# 301            11.1             0.180         0.48            1.50      0.068
# 302             8.3             0.705         0.12            2.60      0.092
# 303             7.4             0.670         0.12            1.60      0.186
# 304             8.4             0.650         0.60            2.10      0.112
# 305            10.3             0.530         0.48            2.50      0.063
# 306             7.6             0.620         0.32            2.20      0.082
# 307            10.3             0.410         0.42            2.40      0.213
# 308            10.3             0.430         0.44            2.40      0.214
# 309             7.4             0.290         0.38            1.70      0.062
# 0               7.4             0.700         0.00            1.90      0.076
# ...
